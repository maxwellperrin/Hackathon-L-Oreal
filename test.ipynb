# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\theov\Desktop\Hackaton_2\Dash\data_merged.csv')

# %%
df.columns
# Out:
# Index(['productName', 'price', 'image', 'category', 'link', 'teint', 'color',
#        'type_peau'],
#       dtype='object')

# %%
df['link'].iloc[1][:-1]
# Out:
# 'https://www.sagacosmetics.com/correcteur-accord-parfait-vanille-r-nu.html#/1847-couleur-vanille_rose_2r_c'

# %%
df['link'] = df['link'].apply(lambda x : x[:-1])

# %%
for link in df['link'] :
    print(link)
# Out:
# https://www.sagacosmetics.com/correcteur-accord-parfait-9d-acajou-nu.html#/1848-couleur-acajou_9d
# https://www.sagacosmetics.com/correcteur-accord-parfait-vanille-r-nu.html#/1847-couleur-vanille_rose_2r_c
# https://www.sagacosmetics.com/creme-anti-age-bb-creme-01-light.html
# https://www.sagacosmetics.com/palette-illuminatrices-la-vie-en-glow-01.html
# https://www.sagacosmetics.com/correcteur-accord-parfait-beige-rose.html
# https://www.sagacosmetics.com/poudre-compacte-accord-parfait-vanille-r.html#/1175-couleur-2r_vanille_rose
# https://www.sagacosmetics.com/fdt-liquide-infaillible-24h-mat-10.html#/1016-couleur-10_porcelain
# https://www.sagacosmetics.com/fdt-liquide-infaillible-total-cover-10.html#/1022-couleur-tc_10_porcelain
# https://www.sagacosmetics.com/fdt-liquide-infaillible-total-cover-13.html#/1023-couleur-tc_13_beige_rose
# https://www.sagacosmetics.com/fdt-liquide-revitalift-serum-200.html#/1047-couleur-200_nude_beige
# ...

# %%
df.to_csv('data_merged.csv', index=False)

# %%
# %pip install derm_ita
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# ...
#    ---------------------------------------- 0.0/25.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/25.0 MB 660.6 kB/s eta 0:00:38
#    ---------------------------------------- 0.1/25.0 MB 787.7 kB/s eta 0:00:32
#    ---------------------------------------- 0.1/25.0 MB 880.9 kB/s eta 0:00:29
#    ---------------------------------------- 0.1/25.0 MB 880.9 kB/s eta 0:00:29
#    ---------------------------------------- 0.1/25.0 MB 880.9 kB/s eta 0:00:29
#    ---------------------------------------- 0.2/25.0 MB 901.1 kB/s eta 0:00:28
#    ---------------------------------------- 0.3/25.0 MB 896.4 kB/s eta 0:00:28
#     --------------------------------------- 0.3/25.0 MB 895.6 kB/s eta 0:00:28
#     --------------------------------------- 0.4/25.0 MB 928.4 kB/s eta 0:00:27
# ...
